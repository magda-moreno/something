# %% [markdown]
# <a href="https://colab.research.google.com/github/magda-moreno/something/blob/main/Lab4_Social_Media_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Lab 4
#
# ## Outline
#
# Repeat exercises from Lab 2, but with the *X SuperBowl* social media dataset
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# <a href="https://colab.research.google.com/github/Stan-Pugsley/is_4487_base/blob/main/Labs/Scripts/lab4_social_media_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Load Libraries
#
# ➡️ Assignment Tasks
# - Load any necessary libraries

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Import Data into Dataframe
#
# ➡️ Assignment Tasks
# - Import data from the X SuperBowl dataset into a dataframe (in GitHub go to Labs > DataSets)
# - Describe or profile the dataframe
# - Make sure you watch for line breaks and emojis that might cause problems with the data import

# %%
df = pd.read_csv (r'/content/gdrive/MyDrive/IS 4487/x_superbowl.csv')

print (df)
# Out:
#       Unnamed: 0                       _id                      created_at  \
# 0              0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
# 1              1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2              2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# 3              3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021
# 4              4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021
# ...          ...                       ...                             ...
# 9751           3  6020fbb89e1aa8e3e7ac0a78  Mon Feb 08 02:01:58 +0000 2021
# 9752           4  6020fbb89e1aa8e3e7ac0a79  Mon Feb 08 01:00:24 +0000 2021
# 9753           5  6020fbb89e1aa8e3e7ac0a7a  Sun Feb 07 23:44:20 +0000 2021
# 9754           6  6020fbb89e1aa8e3e7ac0a7b  Sun Feb 07 23:33:40 +0000 2021
# 9755           7  6020fbb89e1aa8e3e7ac0a7c  Sun Feb 07 23:32:32 +0000 2021
#
#                 id               id_str  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9756 entries, 0 to 9755
# Data columns (total 39 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 9756 non-null   int64
#  1   _id                        9756 non-null   object
#  2   created_at                 9756 non-null   object
#  3   id                         9756 non-null   float64
#  4   id_str                     9756 non-null   int64
#  5   text                       9756 non-null   object
#  6   display_text_range         3222 non-null   object
#  7   source                     9747 non-null   object
#  8   truncated                  9756 non-null   bool
#  9   in_reply_to_status_id      2863 non-null   float64
#  10  in_reply_to_status_id_str  2863 non-null   float64
#  11  in_reply_to_user_id        2985 non-null   float64
#  12  in_reply_to_user_id_str    2985 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0            id        id_str  in_reply_to_status_id  \
# count  9756.000000  9.756000e+03  9.756000e+03           2.863000e+03
# mean   4749.132226  1.358590e+18  1.358590e+18           1.357976e+18
# std    2813.702919  2.346799e+13  2.281055e+13           1.813591e+16
# min       0.000000  1.358560e+18  1.358559e+18           4.475270e+17
# 25%    2308.750000  1.358570e+18  1.358567e+18           1.358560e+18
# 50%    4747.500000  1.358590e+18  1.358587e+18           1.358580e+18
# 75%    7186.250000  1.358610e+18  1.358610e+18           1.358600e+18
# max    9625.000000  1.358630e+18  1.358634e+18           1.358630e+18
#
#        in_reply_to_status_id_str  in_reply_to_user_id  \
# count               2.863000e+03         2.985000e+03
# mean                1.357976e+18         7.661037e+17
# std                 1.813591e+16         5.781080e+17
# min                 4.475267e+17         2.682300e+04
# 25%                 1.358558e+18         1.399829e+09
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                       _id                      created_at  \
# 0           0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
# 1           1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2           2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# 3           3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021
# 4           4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021
#
#              id               id_str  \
# 0  1.358630e+18  1358634152719839233
# 1  1.358630e+18  1358634138639605762
# 2  1.358630e+18  1358634110600826880
# 3  1.358630e+18  1358634090350583809
# 4  1.358630e+18  1358634084537352192
#
#                                                 text display_text_range  \
# 0      @Rebe_Charizard ?????????????????????m(*_ _)m           [16, 45]
# 1  RT @iiiRatcha: ????????????????????"??????????...                NaN
# 2  @kashDAI not you listening to cfm and m&amp;m ...           [9, 140]
# ...

# %% [markdown]
# ## Prepare Data
#
# ➡️ Assignment Tasks
# - Convert any numbers, such as user_mentioned, from strings into numbers
# - Reduce the variables in your dataframe to only those that have useful data
# - Optional: Locate outliers in any of the variables.   Filter them out if they are mistakes; keep them if they are exceptional cases.

# %%
df.drop(['geo', 'coordinates', 'place', 'contributors', 'scopes', 'Unnamed: 0'], axis=1,inplace=True)

df.drop(['extended_tweet', 'extended_entities', 'possibly_sensitive', 'quoted_status_id', 'quoted_status_id_str', 'quoted_status', 'quoted_status_permalink'], axis=1,inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9756 entries, 0 to 9755
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   _id                        9756 non-null   object
#  1   created_at                 9756 non-null   object
#  2   id                         9756 non-null   float64
#  3   id_str                     9756 non-null   int64
#  4   text                       9756 non-null   object
#  5   display_text_range         3222 non-null   object
#  6   source                     9747 non-null   object
#  7   truncated                  9756 non-null   bool
#  8   in_reply_to_status_id      2863 non-null   float64
#  9   in_reply_to_status_id_str  2863 non-null   float64
#  10  in_reply_to_user_id        2985 non-null   float64
#  11  in_reply_to_user_id_str    2985 non-null   float64
#  12  in_reply_to_screen_name    2985 non-null   object
# ...

# %%
df.head()
# Out:
#                         _id                      created_at            id  \
# 0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021  1.358630e+18
# 1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021  1.358630e+18
# 2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021  1.358630e+18
# 3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021  1.358630e+18
# 4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021  1.358630e+18
#
#                 id_str                                               text  \
# 0  1358634152719839233      @Rebe_Charizard ?????????????????????m(*_ _)m
# 1  1358634138639605762  RT @iiiRatcha: ????????????????????"??????????...
# 2  1358634110600826880  @kashDAI not you listening to cfm and m&amp;m ...
# 3  1358634090350583809  RT @_soniashenoy: M&amp;M says \nSsangyong dea...
# 4  1358634084537352192  RT @mmschocolate: This year?s #SuperBowlLV com...
#
#   display_text_range                                             source  \
# ...

# %% [markdown]
# ## Summarize Data
#
# ➡️ Assignment Tasks
# - Create at least two charts to summarize and visualize the data
# - Examples include: Number of posts per device; top 10 posts with highest engagement

# %%
#chart 1

# %%
retween_count = (df['retweet_count'].value_counts()).iloc[:10]
retween_count
# Out:
# 0     9373
# 1      214
# 2       68
# 3       25
# 4       14
# 5       13
# 7        8
# 6        8
# 9        4
# 13       3
# Name: retweet_count, dtype: int64

# %%
retween_count.plot(kind='bar')
# Out:
# <Axes: >

# %%
#chart 2

# %%
reply_count = (df['reply_count'].value_counts()).iloc[:10]

# %%
reply_count.plot(kind='bar')
# Out:
# <Axes: >

# %%
df['lang'].unique()
# Out:
# array(['ja', 'th', 'en', 'hi', 'es', 'ko', 'in', 'ar', 'ht', 'und', 'tr',
#        'tl', 'pt', 'fa', 'zh', 'fr', 'bn', 'et', 'sv', 'ur', 'hu', 'lt',
#        'it', 'eu', 'ru', 'pl', 'de', 'lv', 'mr', 'iw', 'no', 'ne', 'nl',
#        'vi', 'fi', 'da', 'gu', 'cs', 'ca', 'uk'], dtype=object)

# %%
top_used_lang = (df['lang'].value_counts()).iloc[:10]
top_used_lang.plot(kind='bar')
# Out:
# <Axes: >
